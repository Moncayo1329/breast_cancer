# %% [markdown]
# <a href="https://colab.research.google.com/github/Moncayo1329/breast_cancer/blob/main/cancer_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn
print("scikit-learn version:", sklearn.__version__)
# Out:
# scikit-learn version: 1.6.1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
cancer = load_breast_cancer(as_frame=True)
X = cancer.data
y = cancer.target

print("Forma de X (características):", X.shape)   # (569 pacientes, 30 columnas)
print("Forma de y (etiquetas):", y.shape)
print("Clases:", cancer.target_names)             # ['malignant' 'benign']

# Primeras filas para ver cómo se ven
print("\nPrimeras 5 filas de características:")
display(X.head())

# ¿Cuántos benignos vs malignos?
print("\nDistribución de clases:")
print(pd.Series(y).value_counts(normalize=True).round(3))
# Out:
# Forma de X (características): (569, 30)
# Forma de y (etiquetas): (569,)
# Clases: ['malignant' 'benign']
#
# Primeras 5 filas de características:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_breast_cancer
cancer = load_breast_cancer()
X = cancer.data
y = cancer.target

X_train, X_test, y_train, y_test = train_test_split(
      X, y,
      test_size=0.20,
      random_state=42,
      stratify=y
  )
print(f"Entrenamiento: {X_train.shape[0]} ejemplos")
print(f"Prueba: {X_test.shape[0]} ejemplos")

  #modelo simple: K vecinos mas cercanos
model_knn = KNeighborsClassifier(n_neighbors=5)

  #entrenamos

model_knn.fit(X_train, y_train)

  # Predecimos en los datos de prueba

y_pred_knn = model_knn.predict(X_test)

  # que tan bien lo hizo?

acc_knn = accuracy_score(y_test, y_pred_knn)
print(f"Accuracy KNN: {acc_knn:.3f} → {acc_knn*100:.1f}% correctos")
# Out:
# Entrenamiento: 455 ejemplos
# Prueba: 114 ejemplos
# Accuracy KNN: 0.912 → 91.2% correctos
